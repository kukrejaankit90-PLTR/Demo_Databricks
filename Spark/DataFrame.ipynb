# %%
data = [(1, 'Ankit', 'ATT'), (2, 'Ganesh', 'ATT'), (3, 'Ranjeet', 'Verizon')]
schema = "ID int, Name string, Company string"
df=spark.createDataFrame(data,schema)

# %% [markdown]
# Creating a Spark DataFrame

# %%
display(df)
